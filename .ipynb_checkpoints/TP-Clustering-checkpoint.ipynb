# %%
# import spacy
# from es_lemmatizer import lemmatize

import nltk
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import stanza
from sklearn.cluster import KMeans
# Out:
# /home/damifur/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/online_lda.py:31: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   EPS = np.finfo(np.float).eps

# %%
# Bajamos el lemmatizador en español. Peso 226MB
# stanza.download('es')
# nltk.download('stopwords')
# Out:
# ...
# 2021-09-21 23:45:32 INFO: Downloading default packages for language: es (Spanish)...
# ...
# 2021-09-21 23:55:09 INFO: Finished downloading models and saved to /home/damifur/stanza_resources.

# %%
nlp = stanza.Pipeline('es', processors='tokenize,lemma')
noticias = open("clarin.txt", 'r')
texto = noticias.read()
doc = nlp(texto)
# Out:
# 2021-09-22 00:08:44 WARNING: Language es package default expects mwt, which has been added
# 2021-09-22 00:08:44 INFO: Loading these models for language: es (Spanish):
# ...
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# | lemma     | ancora  |
# ...
#
# 2021-09-22 00:08:44 INFO: Use device: cpu
# 2021-09-22 00:08:44 INFO: Loading: tokenize
# 2021-09-22 00:08:44 INFO: Loading: mwt
# 2021-09-22 00:08:44 INFO: Loading: lemma
# 2021-09-22 00:08:44 INFO: Done loading processors!

# %%
# lemmatized = [[token.lemma.lower() for token in sentence if token.lemma.isalpha() and token.lemma not in stopwords.words("spanish")] for sentence in doc.sentences]
lemmatized = []
for sentence in doc.sentences:
    newsentence = []
    for token in sentence.words:
        if token.lemma.isalpha() and token.lemma not in stopwords.words("spanish"):
            newsentence.append(token.lemma.lower())
    lemmatized.append(newsentence)

# %% [markdown]
# Exportamos a un json así no es necesario volver a correr el pre-procesamiento que tarda un buen rato

# %%
with open("clarin-lemmatized.json", 'w') as f:
    try:
        json.dump(lemmatized, f)        
    except e:
        print(e)

# %%
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2)
tf = tf_vectorizer.fit_transform([" ".join(sentence) for sentence in lemmatized])

# %%
km_model = KMeans(n_clusters=50)
km_model.fit(tf)
# Out:
# /home/damifur/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:54: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# /home/damifur/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py:54: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# ...

# %% [markdown]
# Leemos la base de datos de noticias de Clarin. Luego tokenizamos el texto y convertimos todas las palabras a minúsculas

# %%
noticias = open("clarin.txt", 'r')
texto = noticias.read()
tokens = nltk.word_tokenize(texto)
words = [token.lower() for token in tokens if token.isalpha() and token not in stopwords.words("spanish")]
print(words[:50])
# Out:
# ['instalacion', 'y', 'reparacion', 'de', 'aire', 'acondicionado', 'capital', 'opinión', 'info', 'mublet', 'roberto', 'lavagna', 'juan', 'manuel', 'urtubey', 'concentran', 'tres', 'provincias', 'clavea', 'mes', 'elección', 'general', 'roberto', 'lavagna', 'juan', 'manuel', 'urtubey', 'concentran', 'esfuerzos', 'tres', 'provincias', 'populosas', 'pesadas', 'padrón', 'buenos', 'aires', 'córdoba', 'santa', 'fe', 'el', 'martes', 'fórmula', 'presidencial', 'consenso', 'federal', 'volará', 'córdoba', 'raid', 'actividades', 'dos']
# ...

# %%
nlp = stanfordnlp.Pipeline(lang="es")


lemmatized = [wnl.lemmatize(t) for t in words]
print(lemmatized[:50])

# %%
words
# Out:
# ['instalacion',
#  'y',
#  'reparacion',
#  'de',
#  'aire',
#  'acondicionado',
#  'capital',
#  'opinión',
#  'info',
#  'mublet',
#  'roberto',
#  'lavagna',
#  'juan',
#  'manuel',
#  'urtubey',
#  'concentran',
#  'tres',
#  'provincias',
#  'clavea',
#  'me',
#  'elección',
#  'general',
#  'roberto',
#  'lavagna',
#  'juan',
#  'manuel',
#  'urtubey',
#  'concentran',
#  'esfuerzos',
#  'tres',
#  'provincias',
#  'populosas',
#  'pesadas',
#  'padrón',
#  'buenos',
#  'aire',
#  'córdoba',
#  'santa',
#  'fe',
#  'el',
#  'martes',
#  'fórmula',
#  'presidencial',
#  'consenso',
#  'federal',
#  'volará',
#  'córdoba',
#  'raid',
#  'actividades',
#  'do',
#  'días',
#  'el',
#  'ex',
#  'ministro',
#  'disertará',
#  'coloquio',
#  'industriales',
#  'uia',
#  'irá',
#  'facultad',
#  'economía',
#  'derecho',
#  'visitará',
#  'bolsa',
#  'comercio',
#  'encabezará',
#  'recorridas',
#  'candidatos',
#  'locale',
#  'acompañado',
#  'gobernador',
#  'salteño',
#  'su',
# ...

# %%
tf = tf_vectorizer.fit_transform(words)

# %%
tf_vectorizer.get_feature_names()
# Out:
# ['aa',
#  'aaa',
#  'aabe',
#  'aadet',
#  'aadi',
#  'aaib',
#  'aalcc',
#  'aam',
#  'aamr',
#  'aaoc',
#  'aap',
#  'aapp',
#  'aarhus',
#  'aaron',
#  'ab',
#  'ababel',
#  'abad',
#  'abadejo',
#  'abadi',
#  'abadía',
#  'abajo',
#  'abal',
#  'abalanzó',
#  'abalos',
#  'abanderada',
#  'abanderado',
#  'abanderados',
#  'abanderadosarg',
#  'abandona',
#  'abandonaba',
#  'abandonada',
#  'abandonadas',
#  'abandonado',
#  'abandonados',
#  'abandonamos',
#  'abandonan',
#  'abandonando',
#  'abandonar',
#  'abandonara',
#  'abandonaran',
#  'abandonarlas',
#  'abandonarlo',
#  'abandonarnos',
#  'abandonaron',
#  'abandonará',
#  'abandonarán',
#  'abandonaría',
#  'abandone',
#  'abandonemos',
#  'abandonen',
#  'abandono',
#  'abandonos',
#  'abandoné',
#  'abandonó',
#  'abanico',
#  'abaratar',
#  'abarca',
#  'abarcaba',
#  'abarcadora',
#  'abarcan',
#  'abarcar',
#  'abarcará',
#  'abarcativa',
#  'abarcativo',
#  'abarcó',
#  'abaroa',
#  'abarrotada',
# ...

# %% [markdown]
# Lematizamos las palabras

# %%
words = [wnl.lemmatize(w) for w in words]

# %%
# Out:
# 4549561

# %%
# todas = open("noticias.txt", 'w')

# ambito = open("ambito.txt", 'w')
# for nota in db.Ambito.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     ambito.write(nota['title'])
#     ambito.write(nota['text'])
#     ambito.write("\n\n")
# ambito.close()
    
# clarin = open("clarin.txt", 'w')
# for nota in db.Clarin.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     clarin.write(nota['title'])
#     clarin.write(nota['text'])
#     clarin.write("\n\n")
# clarin.close()
    
# cronista = open("cronista.txt", 'w')
# for nota in db.Cronista.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     cronista.write(nota['title'])
#     cronista.write(nota['text'])
#     cronista.write("\n\n")
# cronista.close()
    
# infobae = open("infobae.txt", 'w')
# for nota in db.Infobae.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     infobae.write(nota['title'])
#     infobae.write(nota['text'])
#     infobae.write("\n\n")
# infobae.close()
    
# lid = open("lid.txt", 'w')
# for nota in db.LID.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     lid.write(nota['title'])
#     lid.write(nota['text'])
#     lid.write("\n\n")
# lid.close()
    
# nacion = open("nacion.txt", 'w')
# for nota in db.LaNacion.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     nacion.write(nota['title'])
#     nacion.write(nota['text'])
#     nacion.write("\n\n")
# nacion.close()
    
# p12 = open("p12.txt", 'w')
# for nota in db.P12.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     p12.write(nota['title'])
#     p12.write(nota['text'])
#     p12.write("\n\n")
# p12.close()
         
# po = open("po.txt", 'w')
# for nota in db.PO.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     po.write(nota['title'])
#     po.write(nota['text'])
#     po.write("\n\n")
# po.close()
             
# perfil = open("perfil.txt", 'w')
# for nota in db.Perfil.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     perfil.write(nota['title'])
#     perfil.write(nota['text'])
#     perfil.write("\n\n")
# perfil.close()
                 
# popular = open("popular.txt", 'w')
# for nota in db.Popular.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     popular.write(nota['title'])
#     popular.write(nota['text'])
#     popular.write("\n\n")
# popular.close()
                     
# tiempo = open("tiempo.txt", 'w')
# for nota in db.Tiempo.find():
#     todas.write(nota['title'])
#     todas.write(nota['text'])
#     todas.write("\n\n")
#     tiempo.write(nota['title'])
#     tiempo.write(nota['text'])
#     tiempo.write("\n\n")
# tiempo.close()

# todas.close()
